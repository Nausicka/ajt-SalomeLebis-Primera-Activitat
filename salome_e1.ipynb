# %% [markdown]
# Exercisi 1: Enters

# %% [markdown]
# a

# %%
preu_entrada=8.25

# %%
nombre_entrades=1

# %%
preu_entrada*nombre_entrades
# Out:
# 82.5

# %%
nombre_entrades=5

# %%
preu_entrada*nombre_entrades
# Out:
# 41.25

# %%
nombre_entrades=354

# %%
preu_entrada*nombre_entrades
# Out:
# 2920.5

# %% [markdown]
# b

# %%
nombre_entrades=10

# %%
nombre_entrades-4
# Out:
# 6

# %%
preu_entrada*nombre_entrades
# Out:
# 2920.5

# %% [markdown]
# Exercisi 2

# %%
perpoblacio= 100

# %%
infectats_inicials=10

# %%
taxa_contagi=0.01

# %%
dies=5

# %%
10+(100-10)*(1-(1-0.01)**5)
# Out:
# 14.410895509000008

# %%
infectats=14.41

# %% [markdown]
# Exercisi 3

# %%
import math

# %%
math.pi
# Out:
# 3.141592653589793

# %% [markdown]
# Exercisi 4

# %%
nom="Salome Le Bis"

# %%
primera_lletra=nom[0]

# %%
ultima_lletra=nom[-1]

# %%
tres_lletres=nom[2:5]

# %%
nom_M=nom.upper()

# %%
nom_m=nom.lower()

# %%
llargada_nom=len(nom)

# %%
print(f"Hola, el meu nom es {nom}.\nLa primera lletra del meu nom es {primera_lletra}.\nLultima lletra del meu nom es {ultima_lletra}.\nEls tres caracters entre la posicio 2 i la posicio 5 son {tres_lletres}.\nEl meu nom,amb espais,te {llargada_nom} caracters.\nel meu nom en majuscules es veu aixi {nom_M}.\nEl meu nom en minuscules es veu aixi {nom_m}")
# Out:
# Hola, el meu nom es Salome Le Bis.
# La primera lletra del meu nom es S.
# Lultima lletra del meu nom es s.
# Els tres caracters entre la posicio 2 i la posicio 5 son lom.
# El meu nom,amb espais,te 13 caracters.
# el meu nom en majuscules es veu aixi SALOME LE BIS.
# El meu nom en minuscules es veu aixi salome le bis
